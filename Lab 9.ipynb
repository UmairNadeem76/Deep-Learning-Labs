# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense
from tensorflow.keras.utils import to_categorical

(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

fig, axes = plt.subplots(2, 5, figsize=(10, 5))
axes = axes.flatten() # Flatten the array of axes for easy iteration
for i in range(10):
 img = train_images[train_labels == i][0]
 axes[i].imshow(img, cmap='gray')
 axes[i].set_title(f"Digit: {i}")
 axes[i].axis('off')
plt.tight_layout()
plt.show()

train_images = train_images / 255.0
test_images = test_images / 255.0

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

model = Sequential([
 Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28,
28, 1)),
 MaxPooling2D(pool_size=(2, 2)),
 Conv2D(64, kernel_size=(3, 3), activation='relu'),
 MaxPooling2D(pool_size=(2, 2)),
 Flatten(),
 Dense(128, activation='relu'),
 Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10, batch_size=32, 
validation_split=0.1,verbose=1)

test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9024 - loss: 0.3123 - val_accuracy: 0.9857 - val_loss: 0.0512
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9843 - loss: 0.0491 - val_accuracy: 0.9910 - val_loss: 0.0376
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9910 - loss: 0.0272 - val_accuracy: 0.9897 - val_loss: 0.0397
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9933 - loss: 0.0210 - val_accuracy: 0.9917 - val_loss: 0.0367
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9949 - loss: 0.0152 - val_accuracy: 0.9915 - val_loss: 0.0339
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9959 - loss: 0.0113 - val_accuracy: 0.9910 - val_loss: 0.0415
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9895 - val_loss: 0.0448
# Epoch 8/10
# ...

# %% [markdown]
# HOMEWORK TASKS

# %% [markdown]
# TASK NO : 1 - LOAD AND EXPLORE THE MNIST DATASET

# %%
# Hint: Use mnist.load_data() to load the dataset and print the shapes of data.

from tensorflow.keras.datasets import mnist

# Load and explore the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print("Training data shape:", train_images.shape)
print("Test data shape:", test_images.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)

# %% [markdown]
# TASK NO : 2 - Display Sample Images

# %%
# Hint: Use matplotlib to plot one image of each digit (0-9) from the training set.

import matplotlib.pyplot as plt

# Display Sample Images
fig, axes = plt.subplots(2, 5, figsize=(10, 5))
axes = axes.flatten()  # Flatten the array of axes for easy iteration
for i in range(10):
    img = train_images[train_labels == i][0]
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Digit: {i}")
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# TASK NO : 3 - Normalize the Pixel Values

# %%
# Hint: Scale the pixel values of the images to be between 0 and 1 by dividing by 255.

# Normalize the pixel values
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# TASK NO : 4 - One-Hot Encode the Labels

# %%
# Hint: Use to_categorical from tensorflow.keras.utils to convert the labels to one-hot encoded format.

from tensorflow.keras.utils import to_categorical

# One-Hot Encode the Labels
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# TASK NO : 5 - Build a Simple CNN Model

# %%
# Hint: Create a CNN model with Conv2D, MaxPooling2D, Flatten, and Dense layers.

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Build a Simple CNN Model
model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# TASK NO : 6 - Compile the CNN Model

# %%
# Hint: Use the Adam optimizer, categorical cross-entropy loss, and accuracy as the evaluation metric.

# Compile the CNN Model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#--------------------------------------------------------------------------------------#

# Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=32, validation_split=0.1, verbose=1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9021 - loss: 0.3202 - val_accuracy: 0.9852 - val_loss: 0.0441
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9849 - loss: 0.0497 - val_accuracy: 0.9877 - val_loss: 0.0437
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9908 - loss: 0.0311 - val_accuracy: 0.9858 - val_loss: 0.0480
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9933 - loss: 0.0231 - val_accuracy: 0.9903 - val_loss: 0.0389
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9945 - loss: 0.0176 - val_accuracy: 0.9900 - val_loss: 0.0420
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9958 - loss: 0.0128 - val_accuracy: 0.9895 - val_loss: 0.0402
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9970 - loss: 0.0089 - val_accuracy: 0.9937 - val_loss: 0.0296
# Epoch 8/10
# ...

# %% [markdown]
# LAB TASKS:-

# %% [markdown]
# TASK NO : 1 - In the provided code, the model uses MaxPooling2D layers for downsampling. What if
# we replaced them with AvgPooling2D layers instead? Update the code to reflect this
# change and explain how it might affect the model's performance.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# Load and explore the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Display Sample Images
fig, axes = plt.subplots(2, 5, figsize=(10, 5))
axes = axes.flatten()  # Flatten the array of axes for easy iteration
for i in range(10):
    img = train_images[train_labels == i][0]
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f"Digit: {i}")
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# Normalize the pixel values
train_images = train_images / 255.0
test_images = test_images / 255.0

# Reshape images to add a single channel dimension
train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))

# One-Hot Encode the Labels
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Build a Simple CNN Model
model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    AveragePooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the CNN Model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=32, validation_split=0.1, verbose=1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.8933 - loss: 0.3590 - val_accuracy: 0.9813 - val_loss: 0.0652
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9822 - loss: 0.0604 - val_accuracy: 0.9838 - val_loss: 0.0533
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9871 - loss: 0.0404 - val_accuracy: 0.9900 - val_loss: 0.0408
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9901 - loss: 0.0305 - val_accuracy: 0.9897 - val_loss: 0.0418
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9929 - loss: 0.0226 - val_accuracy: 0.9853 - val_loss: 0.0485
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9944 - loss: 0.0175 - val_accuracy: 0.9907 - val_loss: 0.0333
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9955 - loss: 0.0145 - val_accuracy: 0.9913 - val_loss: 0.0349
# Epoch 8/10
# ...

# %% [markdown]
# TASK NO : 2 - Increase the number of filters in the first convolutional layer to 128. How might it affect the model's learning and performance?

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense
from tensorflow.keras.utils import to_categorical

(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

fig, axes = plt.subplots(2, 5, figsize=(10, 5))
axes = axes.flatten() # Flatten the array of axes for easy iteration
for i in range(10):
 img = train_images[train_labels == i][0]
 axes[i].imshow(img, cmap='gray')
 axes[i].set_title(f"Digit: {i}")
 axes[i].axis('off')
plt.tight_layout()
plt.show()

train_images = train_images / 255.0
test_images = test_images / 255.0

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

model = Sequential([
 Conv2D(128, kernel_size=(3, 3), activation='relu', input_shape=(28,
28, 1)),
 MaxPooling2D(pool_size=(2, 2)),
 Conv2D(64, kernel_size=(3, 3), activation='relu'),
 MaxPooling2D(pool_size=(2, 2)),
 Flatten(),
 Dense(128, activation='relu'),
 Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10, batch_size=32, 
validation_split=0.1,verbose=1)

test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 42s 24ms/step - accuracy: 0.9118 - loss: 0.2877 - val_accuracy: 0.9875 - val_loss: 0.0478
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.9862 - loss: 0.0445 - val_accuracy: 0.9883 - val_loss: 0.0391
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.9919 - loss: 0.0261 - val_accuracy: 0.9895 - val_loss: 0.0425
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - accuracy: 0.9939 - loss: 0.0187 - val_accuracy: 0.9907 - val_loss: 0.0360
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 38s 23ms/step - accuracy: 0.9954 - loss: 0.0133 - val_accuracy: 0.9893 - val_loss: 0.0457
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 39s 23ms/step - accuracy: 0.9961 - loss: 0.0120 - val_accuracy: 0.9917 - val_loss: 0.0362
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 39s 23ms/step - accuracy: 0.9972 - loss: 0.0079 - val_accuracy: 0.9880 - val_loss: 0.0527
# Epoch 8/10
# ...
