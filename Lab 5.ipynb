# %% [markdown]
# # TASK 1 :

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)
plt.scatter(X,y)
plt.show()

# %% [markdown]
# **Get the value of m with OLS**

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X,y)
print('m:',reg.coef_)
print('b',reg.intercept_)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')
# Out:
# m: [78.35063668]
# b 26.15963284313262

# %% [markdown]
# **After applying OLS we get the coefficient, value of m as 78.35 and intercept as 26.15. Now we will implement Gradient descent by taking any random value of intercept and you will see that after performing 2 to 3 iteration we will reach near 26.15 and that is our end goal to implement.
# If I plot the prediction line by OLS then it will look something like this.**

# %% [markdown]
# **Let’s apply Gradient descent assuming slope is constant at 78.35 and a starting value of intercept b is 0. so let us apply the equation and predict the initial value.**

# %%
b=0
y_pred = ((78.35 * X) + b).reshape(4)
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='lightblue',label='b=0')
plt.legend()
plt.show()

# %% [markdown]
# **This is a line when an intercept is zero and Now as we will move forward by calculating the slope and find a new value of b will move towards the red line.**

# %% [markdown]
# **When we calculate the learning rate multiplied by slope is known as step size and to calculate the new intercept we subtract step size from the old intercept and that’s what we have done. And the new intercept is 20.9 hence directly from 0 we have reached 20.9.**

# %%
m=78.35
b=0
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
lr = 0.1
step_size = loss_slope*lr
print(step_size)
b = b - step_size
print('b :' , b)
# Out:
# -20.927763408209216
# b : 20.927763408209216

# %%
b=20.9
loss_slope= -2 * np.sum(y-m*X.ravel()-b)
lr = 0.1
step_size = loss_slope*lr
b=b-step_size
print('b :' , b)
# Out:
# b : 25.107763408209216

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt


X, y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)
plt.scatter(X, y, label='Data')


from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X, y)

plt.plot(X, reg.predict(X), color='red', label='OLS')

m = 78.35
b_values = [0, 20.9, 25.1]

for b in b_values:
    plt.plot(X, (m * X + b), label='b=' + str(round(b, 2)))

plt.legend()
plt.show()

# %% [markdown]
# # TASK 2:

# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
x,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x,y)
print(reg.coef_)
print(reg.intercept_)

b=0
y_pred = ((78.35 * x) + b).reshape(4)
plt.scatter(x,y)
plt.plot(x,reg.predict(x),color="red", label="OLS")
plt.plot(x,y_pred,color="#00a65a", label="b = 0")
plt.legend()
plt.show()

b = 0
m = 78.35
lr = 0.01

epochs = 100

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*x.ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = ((78.35 * x) + b)

  plt.plot(x,y_pred)

plt.scatter(x,y)
# Out:
# [78.35063668]
# 26.15963284313262
